# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')


#Import Numpy and Pandas libraries. 
#Numpy adds support for large, multi-dimensinal arrays and matrics, mathematical functions.
#Pandas is a library for manipulating numerical tables and time series
#seaborn is aPython data visualization library based on matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = pd.read_csv("/content/drive/My Drive/demographical civic engagement/second.csv")

df.info()
df.head()
# Out:
# Mounted at /content/drive
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               5 non-null      object
#  1   Total Both Sexes                   5 non-null      int64
#  2   Men                                5 non-null      int64
#  3   Women                              5 non-null      int64
#  4   16 to 24                           5 non-null      int64
#  5   25 to 34                           5 non-null      int64
#  6   35 to 44                           5 non-null      int64
#  7   45 to 54                           5 non-null      float64
#  8   55 to 64                           5 non-null      int64
#  9   65 and over                        5 non-null      int64
#  10  White                              5 non-null      int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               5 non-null      object
#  1   Total Both Sexes                   5 non-null      int64
#  2   Men                                5 non-null      int64
#  3   Women                              5 non-null      int64
#  4   16 to 24                           5 non-null      int64
#  5   25 to 34                           5 non-null      int64
#  6   35 to 44                           5 non-null      int64
#  7   45 to 54                           5 non-null      float64
#  8   55 to 64                           5 non-null      int64
#  9   65 and over                        5 non-null      int64
#  10  White                              5 non-null      int64
# ...

# %%
test=df

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               5 non-null      object
#  1   Total Both Sexes                   5 non-null      int64
#  2   Men                                5 non-null      int64
#  3   Women                              5 non-null      int64
#  4   16 to 24                           5 non-null      int64
#  5   25 to 34                           5 non-null      int64
#  6   35 to 44                           5 non-null      int64
#  7   45 to 54                           5 non-null      float64
#  8   55 to 64                           5 non-null      int64
#  9   65 and over                        5 non-null      int64
#  10  White                              5 non-null      int64
# ...

# %%
import seaborn as sns
ax= sns.(x="Date",y=df[["Women","Men"]], data=test)
# Out:
#   File "<ipython-input-113-6821d21ce91a>", line 2
#     ax= sns.(x="Date",y=df[["Women","Men"]], data=test)
#             ^
# SyntaxError: invalid syntax

# %%
df.plot(x="Date", y=["Women", "Men"], kind="bar", figsize=(9, 8))
plt.title("Sex")
# Out:
# Text(0.5, 1.0, 'Sex')

# %%
df.plot(x="Date", y=["16 to 24","25 to 34", "35 to 44", "45 to 54", "55 to 64", "65 and over"], kind="bar", figsize=(10, 10))
plt.title("Age")
# Out:
# Text(0.5, 1.0, 'Age')

# %%
import seaborn as sns
# importing libraries
import matplotlib.pyplot as plt
import seaborn

# declaring data
data = [51986, 6086, 2596, 6165]
keys = ['White', 'Black or AA', 'Asian', 'Hispanic or Latino']

# declaring exploding pie

# define Seaborn color palette to use
palette_color = seaborn.color_palette('pastel')

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')
plt.title("Most Recent Race Percentages")
# displaying chart
plt.show()

# %%
df.plot(x="Date", y=["less than high school diploma","high school graduates, no college", "Some college or associates", "Bachelor's or higher"], kind="bar", figsize=(10, 14))
plt.title("Education")
# Out:
# Text(0.5, 1.0, 'Education')

# %%
df.plot(x="Date", y=["Employed Full Time P","Employed Part Time P", "Unemployed P", "Not in Labor Force P"], kind="bar", figsize=(10, 10))
plt.title("Employment Level")
plt.ylabel("Employment Percentages")
# Out:
# Text(0, 0.5, 'Employment Percentages')

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


# draw lineplot
sns.lineplot(y="Total Both Sexes")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-76c8473710c1> in <module>
#       5
#       6 # draw lineplot
# ----> 7 sns.lineplot(y="Total Both Sexes")
#       8 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     690
#     691     variables = _LinePlotter.get_semantics(locals())
# --> 692     p = _LinePlotter(
# ...

# %%
df.plot(x="Date", y=["35 to 44","Employed Part Time"], kind="bar", figsize=(10, 14))
plt.title("Age-Employment correlation")
# Out:
# Text(0.5, 1.0, 'Age-Employment correlation')

# %%
df.plot(x="Date", y=["Black or AA","Employed"], kind="bar", figsize=(10, 14))
plt.title("Race-Employment correlation")
# Out:
# Text(0.5, 1.0, 'Race-Employment correlation')

# %%
df.plot(x="Date", y=["Asian","Black or AA", "White", "Hispanic or Latino", "Bachelor's or higher"], kind="bar", figsize=(10, 14))
plt.title("Race-Education correlation")
# Out:
# Text(0.5, 1.0, 'Race-Education correlation')

# %%
df.plot(x="Date", y=["Asian","Black or AA", "White", "Hispanic or Latino", "Employed"], kind="bar", figsize=(10, 14))
plt.title("Race-Employment correlation")
# Out:
# Text(0.5, 1.0, 'Race-Employment correlation')

# %%
df.plot(x="Date", y=["Women", "Men", "Employed"], kind="bar", figsize=(10, 14))
plt.title("Sex-Employment correlation")
# Out:
# Text(0.5, 1.0, 'Sex-Employment correlation')
